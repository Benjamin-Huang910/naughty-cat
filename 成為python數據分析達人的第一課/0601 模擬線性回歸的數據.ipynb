# %% [markdown]
# 我們認真地來做一下數據分析

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 準備模擬的資料
# ### 做一條直線
# 我們來一條線，比如說
# $$f(x)=1.2x+8$$
# 準備好50個點

# %%
x=np.linspace(0,5,50)

# %% [markdown]
# 畫出圖形來

# %%
y=1.2*x+0.8

# %%
plt.scatter(x,y)
plt.plot(x,y,"r")

# %% [markdown]
# ### 加入noise項，看起來更真實
# 大概的想法是，我們真實世界的問題，化成函數，我們假設背後有個美好的函數。但相信我們很少看到真實世界的資料那麼漂亮。在統計上，我們就是假設
# f(x)+誤差項
# 也就是都有個noise項

# %%
y=1.2*x+0.8+0.6*np.random.randn(50)

# %%
plt.plot(x,1.2*x+0.8,'r')
plt.scatter(x,y)
