# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([1,2,3,4,54,76,767,3,32])

# %%
plt.plot(np.random.randn(100))

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
