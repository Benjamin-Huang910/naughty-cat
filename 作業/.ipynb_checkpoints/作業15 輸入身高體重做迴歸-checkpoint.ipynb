# %%
count=1
Male_H=[]   #宣告一個空的串列變數名稱為Male_H
Male_W=[]
#透過while迴圈產生串列
print('請依序輸入30個男生的身高以及體重，每輸入完一個身高跟體重後請按Enter，再接著輸入下一個:')
while count<=30:
    line1 = input('輸入第'+str(count)+'個身高:')  #使用者輸入
    line2 = input('輸入第'+str(count)+'個體重:')  #使用者輸入
    if line1.isdecimal():
        data=int(line1)  #資料型態轉換
        Male_H.append(data)  #將data附加到Male_H這個List中
    else:
        print(f"剛剛輸入的第{count:3d}個身高打錯囉，顆顆")
    if line2.isdecimal():
        data=int(line2)  #資料型態轉換
        Male_W.append(data)  #將data附加到Male_W這個List中
    else:
        print(f"剛剛輸入的第{count:3d}個體重打錯囉，顆顆")
    count+=1

print('已完成輸入\n')
print("男生身高:",Male_H)
print("男生體重:",Male_W)
H_bar=sum(Male_H)/len(Male_H)
W_bar=sum(Male_W)/len(Male_W)
H_d=[]
W_d=[]
H_dXW_d=[]
H_dXH_d=[]
for i in range(len(Male_H)):
    h=Male_H[i]-H_bar
    H_d.append(h)
for j in range (len(Male_W)):
    w=Male_W[j]-W_bar
    W_d.append(w)
for k in range(len(Male_H)):
    hw=H_d[k]*W_d[k]
    H_dXW_d.append(hw)
離均差乘積和=sum(H_dXW_d)
for i in range(len(Male_H)):
    q=(Male_H[i]-H_bar)*(Male_H[i]-H_bar)
    H_dXH_d.append(q)
離均差平方和=sum(H_dXH_d)
b1=離均差乘積和/離均差平方和
print(b1)
b0=W_bar-b1*H_bar
print(b0)
print("W(男生)="+str(b0)+"+"+str(b1)+"H(男生)")
# Out:
# 請依序輸入30個男生的身高以及體重，每輸入完一個身高跟體重後請按Enter，再接著輸入下一個:
# 輸入第1個身高:186
# 輸入第1個體重:84
# 輸入第2個身高:180
# 輸入第2個體重:73
# 輸入第3個身高:172
# 輸入第3個體重:77
# 輸入第4個身高:185
# 輸入第4個體重:65
# 輸入第5個身高:171
# 輸入第5個體重:72
# 輸入第6個身高:170
# 輸入第6個體重:56
# 輸入第7個身高:175
# 輸入第7個體重:52
# 輸入第8個身高:168
# 輸入第8個體重:61
# 輸入第9個身高:189
# 輸入第9個體重:86
# 輸入第10個身高:184
# 輸入第10個體重:70
# 輸入第11個身高:187
# 輸入第11個體重:78
# 輸入第12個身高:172
# 輸入第12個體重:52
# 輸入第13個身高:179
# 輸入第13個體重:56
# 輸入第14個身高:164
# 輸入第14個體重:53
# 輸入第15個身高:175
# 輸入第15個體重:109
# 輸入第16個身高:176
# 輸入第16個體重:115
# 輸入第17個身高:172
# 輸入第17個體重:78
# 輸入第18個身高:181
# 輸入第18個體重:79
# 輸入第19個身高:183
# 輸入第19個體重:90
# 輸入第20個身高:186
# 輸入第20個體重:95
# 輸入第21個身高:174
# 輸入第21個體重:65
# 輸入第22個身高:173
# 輸入第22個體重:62
# 輸入第23個身高:174
# 輸入第23個體重:69
# 輸入第24個身高:177
# 輸入第24個體重:62
# 輸入第25個身高:167
# 輸入第25個體重:59
# 輸入第26個身高:172
# 輸入第26個體重:68
# 輸入第27個身高:173
# 輸入第27個體重:65
# 輸入第28個身高:162
# 輸入第28個體重:50
# 輸入第29個身高:171
# 輸入第29個體重:70
# 輸入第30個身高:178
# 輸入第30個體重:95
# 已完成輸入
#
# 男生身高: [186, 180, 172, 185, 171, 170, 175, 168, 189, 184, 187, 172, 179, 164, 175, 176, 172, 181, 183, 186, 174, 173, 174, 177, 167, 172, 173, 162, 171, 178]
# 男生體重: [84, 73, 77, 65, 72, 56, 52, 61, 86, 70, 78, 52, 56, 53, 109, 115, 78, 79, 90, 95, 65, 62, 69, 62, 59, 68, 65, 50, 70, 95]
# 1.1600704024355435
# -131.81771477499757
# W(男生)=-131.81771477499757+1.1600704024355435H(男生)

# %%
count=1
Female_H=[]   #宣告一個空的串列變數名稱為Female_H
Female_W=[]
#透過while迴圈產生串列
print('請依序輸入30個女生的身高以及體重，每輸入完一個身高跟體重後請按Enter，再接著輸入下一個:')
while count<=30:
    line1 = input('輸入第'+str(count)+'個身高:')  #使用者輸入
    line2 = input('輸入第'+str(count)+'個體重:')  #使用者輸入
    if line1.isdecimal():
        data=int(line1)  #資料型態轉換
        Female_H.append(data)  #將data附加到Female_H這個List中
    else:
        print(f"剛剛輸入的第{count:3d}個身高打錯囉，顆顆")
    if line2.isdecimal():
        data=int(line2)  #資料型態轉換
        Female_W.append(data)  #將data附加到Female_W這個List中
    else:
        print(f"剛剛輸入的第{count:3d}個體重打錯囉，顆顆")
    count+=1

print('已完成輸入\n')
print("女生身高:",Female_H)
print("女生體重:",Female_W)
H_bar=sum(Female_H)/len(Female_H)
W_bar=sum(Female_W)/len(Female_W)
H_d=[]
W_d=[]
H_dXW_d=[]
H_dXH_d=[]
for i in range(len(Female_H)):
    h=Female_H[i]-H_bar
    H_d.append(h)
for j in range (len(Female_W)):
    w=Female_W[j]-W_bar
    W_d.append(w)
for k in range(len(Female_H)):
    hw=H_d[k]*W_d[k]
    H_dXW_d.append(hw)
離均差乘積和=sum(H_dXW_d)
for i in range(len(Female_H)):
    q=(Female_H[i]-H_bar)*(Female_H[i]-H_bar)
    H_dXH_d.append(q)
離均差平方和=sum(H_dXH_d)
b1=離均差乘積和/離均差平方和
print(b1)
b0=W_bar-b1*H_bar
print(b0)
print("W(女生)="+str(b0)+"+"+str(b1)+"H(女生)")
# Out:
# 請依序輸入30個女生的身高以及體重，每輸入完一個身高跟體重後請按Enter，再接著輸入下一個:
# 輸入第1個身高:148
# 輸入第1個體重:38
# 輸入第2個身高:155
# 輸入第2個體重:42
# 輸入第3個身高:164
# 輸入第3個體重:56
# 輸入第4個身高:174
# 輸入第4個體重:62
# 輸入第5個身高:160
# 輸入第5個體重:44
# 輸入第6個身高:152
# 輸入第6個體重:41
# 輸入第7個身高:160
# 輸入第7個體重:46
# 輸入第8個身高:158
# 輸入第8個體重:41
# 輸入第9個身高:160
# 輸入第9個體重:43
# 輸入第10個身高:156
# 輸入第10個體重:47
# 輸入第11個身高:167
# 輸入第11個體重:53
# 輸入第12個身高:149
# 輸入第12個體重:40
# 輸入第13個身高:151
# 輸入第13個體重:40
# 輸入第14個身高:162
# 輸入第14個體重:51
# 輸入第15個身高:161
# 輸入第15個體重:50
# 輸入第16個身高:158
# 輸入第16個體重:44
# 輸入第17個身高:159
# 輸入第17個體重:42
# 輸入第18個身高:164
# 輸入第18個體重:54
# 輸入第19個身高:165
# 輸入第19個體重:53
# 輸入第20個身高:171
# 輸入第20個體重:59
# 輸入第21個身高:169
# 輸入第21個體重:56
# 輸入第22個身高:175
# 輸入第22個體重:61
# 輸入第23個身高:163
# 輸入第23個體重:51
# 輸入第24個身高:160
# 輸入第24個體重:50
# 輸入第25個身高:154
# 輸入第25個體重:46
# 輸入第26個身高:157
# 輸入第26個體重:53
# 輸入第27個身高:156
# 輸入第27個體重:50
# 輸入第28個身高:162
# 輸入第28個體重:49
# 輸入第29個身高:165
# 輸入第29個體重:60
# 輸入第30個身高:168
# 輸入第30個體重:57
# 已完成輸入
#
# 女生身高: [148, 155, 164, 174, 160, 152, 160, 158, 160, 156, 167, 149, 151, 162, 161, 158, 159, 164, 165, 171, 169, 175, 163, 160, 154, 157, 156, 162, 165, 168]
# 女生體重: [38, 42, 56, 62, 44, 41, 46, 41, 43, 47, 53, 40, 40, 51, 50, 44, 42, 54, 53, 59, 56, 61, 51, 50, 46, 53, 50, 49, 60, 57]
# 0.9019934795052388
# -95.71048505512557
# W(女生)=-95.71048505512557+0.9019934795052388H(女生)
