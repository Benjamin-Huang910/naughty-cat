# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(1232)
# Out:
# 0.4756297378585802

# %%
plot([2,43,-85,32,45])

# %%
randn(10)
# Out:
# array([-0.52206277, -1.0983076 , -0.15705121, -1.28447877, -1.51830775,
#         0.01643537,  1.02368194,  0.75222179,  1.80271176, -0.24846881])

# %%
plot(randn(10))

# %%
plot([1,2,3,4],[2,3,34,65])
