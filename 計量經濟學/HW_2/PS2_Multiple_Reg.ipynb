# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.formula.api as smf

# %% [markdown]
# ### Data Preparation

# %%
stkdata = pd.read_sas('stkdata.sas7bdat', encoding='utf-8')

print(stkdata.head())
# Out:
#         DATE TICKER       RET
# 0 2011-01-31   AAPL  0.051959
# 1 2011-02-28   AAPL  0.040935
# 2 2011-03-31   AAPL -0.013314
# 3 2011-04-29   AAPL  0.004656
# 4 2011-05-31   AAPL -0.006569

# %%
stkdata = stkdata[stkdata['TICKER'].isin(['AAPL', 'INTC', 'MSFT'])]

# %%
mktdata = pd.read_sas('mktdata.sas7bdat', encoding='utf-8')

# %%
Regdata = pd.merge(stkdata, mktdata, on='DATE')

# %%
Regdata['RETRF'] = Regdata['RET'] - Regdata['RF']

# %% [markdown]
# ### CAPM estimation

# %%
for TIC in ['AAPL', 'INTC', 'MSFT']:
    tempdf = Regdata[Regdata['TICKER'] == TIC]
    mdl = smf.ols('RETRF ~ MKTRF', data=tempdf).fit()
    print()
    print(TIC)
    print()
    print(mdl.summary())
# Out:
# AAPL
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     52.02
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           5.71e-11
# Time:                        02:54:01   Log-Likelihood:                 155.82
# No. Observations:                 120   AIC:                            -307.6
# Df Residuals:                     118   BIC:                            -302.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0122      0.006      1.930      0.056      -0.000       0.025
# MKTRF          1.0677      0.148      7.212      0.000       0.775       1.361
# ==============================================================================
# Omnibus:                        6.230   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                6.648
# Skew:                          -0.353   Prob(JB):                       0.0360
# Kurtosis:                       3.911   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# INTC
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     31.24
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.49e-07
# Time:                        02:54:01   Log-Likelihood:                 169.22
# No. Observations:                 120   AIC:                            -334.4
# Df Residuals:                     118   BIC:                            -328.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0030      0.006      0.535      0.594      -0.008       0.014
# MKTRF          0.7400      0.132      5.589      0.000       0.478       1.002
# ==============================================================================
# Omnibus:                       12.155   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               20.961
# Skew:                          -0.431   Prob(JB):                     2.81e-05
# Kurtosis:                       4.857   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# MSFT
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     54.90
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           2.08e-11
# Time:                        02:54:01   Log-Likelihood:                 194.66
# No. Observations:                 120   AIC:                            -385.3
# Df Residuals:                     118   BIC:                            -379.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0114      0.005      2.503      0.014       0.002       0.020
# MKTRF          0.7936      0.107      7.409      0.000       0.581       1.006
# ==============================================================================
# Omnibus:                        9.145   Durbin-Watson:                   2.308
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               14.062
# Skew:                           0.338   Prob(JB):                     0.000884
# Kurtosis:                       4.535   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Fama and French 3-Factor Model Estimation and F-Test against CAPM

# %%
for TIC in ['AAPL', 'INTC', 'MSFT']:
    tempdf = Regdata[Regdata['TICKER'] == TIC]
    mdl = smf.ols('RETRF ~ MKTRF + SMB + HML', data=tempdf).fit()
    print()
    print(TIC)
    print()
    print(mdl.summary())
    print()
    hypotheses = '(SMB = 0), (HML=0)'
    f_test = mdl.f_test(hypotheses)
    print(f_test)
# Out:
# AAPL
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     24.50
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           2.36e-12
# Time:                        02:54:01   Log-Likelihood:                 163.36
# No. Observations:                 120   AIC:                            -318.7
# Df Residuals:                     116   BIC:                            -307.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0064      0.006      1.037      0.302      -0.006       0.019
# MKTRF          1.2900      0.155      8.349      0.000       0.984       1.596
# SMB           -0.5719      0.268     -2.135      0.035      -1.102      -0.041
# HML           -0.6870      0.224     -3.064      0.003      -1.131      -0.243
# ==============================================================================
# Omnibus:                        9.554   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               12.486
# Skew:                          -0.436   Prob(JB):                      0.00194
# Kurtosis:                       4.318   Cond. No.                         48.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[7.76221642]]), p=0.0006857881695827276, df_denom=116, df_num=2>
#
# INTC
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     11.05
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.95e-06
# Time:                        02:54:01   Log-Likelihood:                 170.21
# No. Observations:                 120   AIC:                            -332.4
# Df Residuals:                     116   BIC:                            -321.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0016      0.006      0.267      0.790      -0.010       0.013
# MKTRF          0.8251      0.146      5.654      0.000       0.536       1.114
# SMB           -0.3189      0.253     -1.261      0.210      -0.820       0.182
# HML           -0.0948      0.212     -0.448      0.655      -0.514       0.325
# ==============================================================================
# Omnibus:                       15.463   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.157
# Skew:                          -0.503   Prob(JB):                     1.72e-07
# Kurtosis:                       5.285   Cond. No.                         48.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[0.96590573]]), p=0.38367821908879984, df_denom=116, df_num=2>
#
# MSFT
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.415
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.77e-13
# Time:                        02:54:01   Log-Likelihood:                 203.90
# No. Observations:                 120   AIC:                            -399.8
# Df Residuals:                     116   BIC:                            -388.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0079      0.004      1.800      0.074      -0.001       0.017
# MKTRF          0.9968      0.110      9.045      0.000       0.779       1.215
# SMB           -0.7590      0.191     -3.973      0.000      -1.137      -0.381
# HML           -0.2313      0.160     -1.446      0.151      -0.548       0.085
# ==============================================================================
# Omnibus:                        7.926   Durbin-Watson:                   2.322
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               13.024
# Skew:                           0.230   Prob(JB):                      0.00149
# Kurtosis:                       4.547   Cond. No.                         48.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[9.66030864]]), p=0.00013165977362498155, df_denom=116, df_num=2>

# %% [markdown]
# ### Collinearity (VIF)

# %%
mdl_VIF1 = smf.ols('MKTRF ~ SMB + HML', data=mktdata).fit()
print('VIF1')
print()
print(mdl_VIF1.summary())
print()

mdl_VIF2 = smf.ols('SMB ~ MKTRF + HML', data=mktdata).fit()
print('VIF2')
print()
print(mdl_VIF2.summary())
print()

mdl_VIF3 = smf.ols('HML ~ MKTRF + SMB', data=mktdata).fit()
print('VIF3')
print()
print(mdl_VIF3.summary())
print()
# Out:
# VIF1
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  MKTRF   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     12.52
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.18e-05
# Time:                        02:54:01   Log-Likelihood:                 224.47
# No. Observations:                 120   AIC:                            -442.9
# Df Residuals:                     117   BIC:                            -434.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0126      0.003      3.607      0.000       0.006       0.020
# SMB            0.6452      0.149      4.338      0.000       0.351       0.940
# HML            0.2227      0.133      1.680      0.096      -0.040       0.485
# ==============================================================================
# Omnibus:                        1.014   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.581
# Skew:                          -0.103   Prob(JB):                        0.748
# Kurtosis:                       3.272   Cond. No.                         45.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF2
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SMB   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     11.65
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           2.44e-05
# Time:                        02:54:01   Log-Likelihood:                 290.49
# No. Observations:                 120   AIC:                            -575.0
# Df Residuals:                     117   BIC:                            -566.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0022      0.002     -1.048      0.297      -0.006       0.002
# MKTRF          0.2147      0.049      4.338      0.000       0.117       0.313
# HML            0.0894      0.077      1.162      0.248      -0.063       0.242
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                2.463
# Skew:                           0.223   Prob(JB):                        0.292
# Kurtosis:                       2.458   Cond. No.                         39.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF3
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    HML   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     3.388
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):             0.0371
# Time:                        02:54:01   Log-Likelihood:                 269.13
# No. Observations:                 120   AIC:                            -532.3
# Df Residuals:                     117   BIC:                            -523.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0058      0.002     -2.325      0.022      -0.011      -0.001
# MKTRF          0.1058      0.063      1.680      0.096      -0.019       0.230
# SMB            0.1276      0.110      1.162      0.248      -0.090       0.345
# ==============================================================================
# Omnibus:                       13.575   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               42.765
# Skew:                          -0.138   Prob(JB):                     5.17e-10
# Kurtosis:                       5.912   Cond. No.                         47.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Constructing D Variable

# %%
Regdata.loc[Regdata['MKTRF']>=0, 'D'] =1
Regdata.loc[Regdata['MKTRF']< 0, 'D'] =0

# %%
# I picked .head(15) because it takes the fifth month of the sample to see the first D=0

Regdata.head(15)
# Out:
#          DATE TICKER       RET     SMB     HML   MKTRF      RF     UMD  \
# 0  2011-01-31   AAPL  0.051959 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 1  2011-01-31   INTC  0.020447 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 2  2011-01-31   MSFT -0.006628 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 3  2011-02-28   AAPL  0.040935  0.0153  0.0129  0.0349  0.0001  0.0208
# 4  2011-02-28   INTC  0.008910  0.0153  0.0129  0.0349  0.0001  0.0208
# 5  2011-02-28   MSFT -0.035528  0.0153  0.0129  0.0349  0.0001  0.0208
# 6  2011-03-31   AAPL -0.013314  0.0258 -0.0176  0.0046  0.0001  0.0352
# 7  2011-03-31   INTC -0.060084  0.0258 -0.0176  0.0046  0.0001  0.0352
# 8  2011-03-31   MSFT -0.044771  0.0258 -0.0176  0.0046  0.0001  0.0352
# 9  2011-04-29   AAPL  0.004656 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 10 2011-04-29   INTC  0.147175 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 11 2011-04-29   MSFT  0.020874 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 12 2011-05-31   AAPL -0.006569 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
# 13 2011-05-31   INTC -0.019819 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
# 14 2011-05-31   MSFT -0.028935 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
#
#        RETRF    D
# 0   0.051859  1.0
# 1   0.020347  1.0
# 2  -0.006728  1.0
# 3   0.040835  1.0
# 4   0.008810  1.0
# 5  -0.035628  1.0
# 6  -0.013414  1.0
# 7  -0.060184  1.0
# 8  -0.044871  1.0
# 9   0.004656  1.0
# 10  0.147175  1.0
# 11  0.020874  1.0
# 12 -0.006569  0.0
# 13 -0.019819  0.0
# 14 -0.028935  0.0

# %% [markdown]
# ### Chow Test

# %%
Regdata['DMKTRF'] = Regdata['MKTRF']*Regdata['D']
Regdata['DSMB'] = Regdata['SMB']*Regdata['D']
Regdata['DHML'] = Regdata['HML']*Regdata['D']

# %%
Regdata.head(15)
# Out:
#          DATE TICKER       RET     SMB     HML   MKTRF      RF     UMD  \
# 0  2011-01-31   AAPL  0.051959 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 1  2011-01-31   INTC  0.020447 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 2  2011-01-31   MSFT -0.006628 -0.0252  0.0082  0.0199  0.0001 -0.0029
# 3  2011-02-28   AAPL  0.040935  0.0153  0.0129  0.0349  0.0001  0.0208
# 4  2011-02-28   INTC  0.008910  0.0153  0.0129  0.0349  0.0001  0.0208
# 5  2011-02-28   MSFT -0.035528  0.0153  0.0129  0.0349  0.0001  0.0208
# 6  2011-03-31   AAPL -0.013314  0.0258 -0.0176  0.0046  0.0001  0.0352
# 7  2011-03-31   INTC -0.060084  0.0258 -0.0176  0.0046  0.0001  0.0352
# 8  2011-03-31   MSFT -0.044771  0.0258 -0.0176  0.0046  0.0001  0.0352
# 9  2011-04-29   AAPL  0.004656 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 10 2011-04-29   INTC  0.147175 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 11 2011-04-29   MSFT  0.020874 -0.0037 -0.0243  0.0290  0.0000  0.0006
# 12 2011-05-31   AAPL -0.006569 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
# 13 2011-05-31   INTC -0.019819 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
# 14 2011-05-31   MSFT -0.028935 -0.0058 -0.0205 -0.0127  0.0000 -0.0057
#
#        RETRF    D  DMKTRF    DSMB    DHML
# 0   0.051859  1.0  0.0199 -0.0252  0.0082
# 1   0.020347  1.0  0.0199 -0.0252  0.0082
# 2  -0.006728  1.0  0.0199 -0.0252  0.0082
# 3   0.040835  1.0  0.0349  0.0153  0.0129
# 4   0.008810  1.0  0.0349  0.0153  0.0129
# 5  -0.035628  1.0  0.0349  0.0153  0.0129
# 6  -0.013414  1.0  0.0046  0.0258 -0.0176
# 7  -0.060184  1.0  0.0046  0.0258 -0.0176
# 8  -0.044871  1.0  0.0046  0.0258 -0.0176
# 9   0.004656  1.0  0.0290 -0.0037 -0.0243
# 10  0.147175  1.0  0.0290 -0.0037 -0.0243
# 11  0.020874  1.0  0.0290 -0.0037 -0.0243
# 12 -0.006569  0.0 -0.0000 -0.0000 -0.0000
# 13 -0.019819  0.0 -0.0000 -0.0000 -0.0000
# 14 -0.028935  0.0 -0.0000 -0.0000 -0.0000

# %%
for TIC in ['AAPL', 'INTC', 'MSFT']:
    tempdf = Regdata[Regdata['TICKER'] == TIC]
    mdl = smf.ols('RETRF ~ D + MKTRF + SMB + HML + DMKTRF + DSMB + DHML', data=tempdf).fit()
    print()
    print(TIC)
    print()
    print(mdl.summary())
    print()
    hypotheses = '(D=0), (DMKTRF=0), (DSMB = 0), (DHML=0)'
    f_test = mdl.f_test(hypotheses)
    print(f_test)
# Out:
# AAPL
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     11.01
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.59e-10
# Time:                        02:54:01   Log-Likelihood:                 165.33
# No. Observations:                 120   AIC:                            -314.7
# Df Residuals:                     112   BIC:                            -292.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0058      0.016     -0.373      0.710      -0.037       0.025
# D              0.0186      0.019      0.982      0.328      -0.019       0.056
# MKTRF          1.0557      0.391      2.697      0.008       0.280       1.831
# SMB           -0.9508      0.451     -2.108      0.037      -1.844      -0.057
# HML           -0.2899      0.358     -0.810      0.420      -0.999       0.420
# DMKTRF         0.0578      0.478      0.121      0.904      -0.889       1.005
# DSMB           0.6220      0.562      1.107      0.271      -0.491       1.735
# DHML          -0.6633      0.468     -1.416      0.159      -1.591       0.265
# ==============================================================================
# Omnibus:                        9.759   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               14.167
# Skew:                          -0.397   Prob(JB):                     0.000839
# Kurtosis:                       4.484   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[0.93349839]]), p=0.4473032605168632, df_denom=112, df_num=4>
#
# INTC
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.256
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     5.512
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           1.82e-05
# Time:                        02:54:01   Log-Likelihood:                 172.89
# No. Observations:                 120   AIC:                            -329.8
# Df Residuals:                     112   BIC:                            -307.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0054      0.015     -0.372      0.711      -0.034       0.024
# D              0.0110      0.018      0.615      0.540      -0.024       0.046
# MKTRF          0.9299      0.368      2.530      0.013       0.202       1.658
# SMB           -0.9695      0.423     -2.290      0.024      -1.808      -0.131
# HML           -0.2786      0.336     -0.829      0.409      -0.945       0.388
# DMKTRF        -0.2215      0.449     -0.494      0.623      -1.111       0.668
# DSMB           1.0194      0.527      1.933      0.056      -0.026       2.064
# DHML           0.3450      0.440      0.785      0.434      -0.526       1.216
# ==============================================================================
# Omnibus:                       12.866   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               26.049
# Skew:                          -0.389   Prob(JB):                     2.21e-06
# Kurtosis:                       5.146   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[1.27822637]]), p=0.28282150774249654, df_denom=112, df_num=4>
#
# MSFT
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  RETRF   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     11.77
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):           3.68e-11
# Time:                        02:54:01   Log-Likelihood:                 204.82
# No. Observations:                 120   AIC:                            -393.6
# Df Residuals:                     112   BIC:                            -371.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0028      0.011     -0.247      0.805      -0.025       0.019
# D              0.0167      0.014      1.223      0.224      -0.010       0.044
# MKTRF          0.8636      0.282      3.066      0.003       0.305       1.422
# SMB           -0.8307      0.324     -2.560      0.012      -1.474      -0.188
# HML           -0.2777      0.258     -1.078      0.283      -0.788       0.233
# DMKTRF         0.0102      0.344      0.030      0.976      -0.671       0.692
# DSMB           0.1367      0.404      0.338      0.736      -0.664       0.938
# DHML           0.0955      0.337      0.283      0.777      -0.572       0.763
# ==============================================================================
# Omnibus:                        7.439   Durbin-Watson:                   2.353
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):               12.135
# Skew:                           0.199   Prob(JB):                      0.00232
# Kurtosis:                       4.506   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# <F test: F=array([[0.43242231]]), p=0.7849502619891969, df_denom=112, df_num=4>
